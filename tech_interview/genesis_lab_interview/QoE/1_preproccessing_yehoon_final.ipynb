# %%
import pandas as pd
from collections import Counter
from sklearn import preprocessing

# %%
rdf = pd.read_pickle('../data/concated_all_1.pkl')
rdf.shape, rdf.columns
# Out:
# ((25050, 39),
#  Index(['avgDecodingTime', 'bufferedDuration', 'bufferings', 'contentUrl',
#         'currentPosition', 'device', 'deviceInfo.deviceId', 'deviceInfo.model',
#         'deviceInfo.os', 'deviceInfo.osVersion', 'deviceInfo.player',
#         'errorCode', 'errorString', 'estimatedBandwidth', 'event',
#         'fragmentSum.bitrate', 'fragmentSum.downloadTime',
#         'fragmentSum.duration', 'fragmentSum.fragmentIndex', 'fragmentSum.size',
#         'fragments', 'frameDropped', 'licenseInfo.drmSystem',
#         'licenseInfo.elapsedTime', 'licenseInfo.laUrl', 'maxDecodingTime',
#         'networkChanged', 'networkErrors', 'networkInfo.carrier.mcc',
#         'networkInfo.carrier.mnc', 'networkInfo.carrier.name',
#         'networkInfo.type', 'position', 'qoeContentId', 'qualityChanged',
#         'redirectUrl', 'sessionId', 'timestamp', 'userEvents'],
#        dtype='object'))

# %%
rdf = rdf.reset_index(drop=True).drop([0]).reset_index(drop=True)
rdf.head()
# Out:
#   avgDecodingTime bufferedDuration  \
# 0               0              441
# 1               3                0
# 2               0               59
# 3               5               39
# 4               0               33
#
#                                           bufferings  \
# 0  [{'currentTime': 1541470583, 'duration': 146},...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'currentTime': 1541471265, 'duration': 28}, ...
#
#                                           contentUrl currentPosition  \
# 0  http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 1  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.58277e+06
# 2  http://abc-streaming.akamaized.net/g/mpd/d/mai...     6.44276e+06
# 3  http://abc-streaming.akamaized.net/g/mpd/d/mai...      2.5053e+06
# 4  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.44438e+06
#
#           device deviceInfo.deviceId deviceInfo.model deviceInfo.os  \
# 0    Android 7.0    9c6b4094efab9501          JP_P00A       Android
# 1  Android 8.0.0    9a98d9a82b079bc7           SO-02K       Android
# 2  Android 8.0.0    61daf34a597f3385           SO-01K       Android
# 3  Android 8.0.0    d652e343f2a8b2e0           SC-03K       Android
# 4  Android 8.0.0    a88594adebc17552           SC-02K       Android
#
#   deviceInfo.osVersion                        ...                          \
# 0                  7.0                        ...
# 1                8.0.0                        ...
# 2                8.0.0                        ...
# 3                8.0.0                        ...
# 4                8.0.0                        ...
#
#   networkInfo.carrier.mnc networkInfo.carrier.name networkInfo.type  \
# 0                     NaN                      NaN             WiFi
# 1                      10               NTT DOCOMO             WiFi
# 2                      10               NTT DOCOMO              LTE
# 3                      10               NTT DOCOMO             WiFi
# 4                      10               NTT DOCOMO             WiFi
#
#       position qoeContentId  \
# 0            0     11005782
# 1  2.58277e+06     10894547
# 2  6.44276e+06     10656711
# 3   2.5053e+06     10987587
# 4  2.44438e+06     10966088
#
#                                       qualityChanged  \
# 0  [{'bandwidth': 429745, 'timestamp': 1541470582...
# 1                                                 []
# 2  [{'bandwidth': 1343060, 'timestamp': 154147065...
# 3                                                 []
# 4  [{'bandwidth': 427182, 'timestamp': 1541471263...
#
#                                          redirectUrl       sessionId  \
# 0  http://abc-streaming.akamaized.net/g/mpd/d/mai...  43754809210075
# 1  http://abc-streaming.akamaized.net/g/mpd/d/mai...   9556708911304
# 2  http://abc-streaming.akamaized.net/g/mpd/d/mai...  40367776409166
# 3  http://abc-streaming.akamaized.net/g/mpd/d/mai...  64388793530698
# 4  http://abc-streaming.akamaized.net/g/mpd/d/mai...  66221138236843
#
#     timestamp                                         userEvents
# 0  1541470586  [{'action': 'seek', 'position': 0}, {'action':...
# 1  1541470588                                                 []
# 2  1541470657         [{'action': 'pause', 'position': 6442653}]
# 3  1541470656                                                 []
# 4  1541471274  [{'action': 'seek', 'position': 0}, {'action':...
#
# [5 rows x 39 columns]

# %%
rdf.shape
# Out:
# (25049, 39)

# %% [markdown]
# ## Drop columns

# %%
# feature selection으로 이미 처리 완료 -> 필요 없는 columns
df = rdf.drop(['deviceInfo.deviceId', 'deviceInfo.model', 'deviceInfo.os', 'deviceInfo.osVersion', 'deviceInfo.player', 'event', 'licenseInfo.laUrl',  'networkChanged', 'networkInfo.carrier.mcc', 'networkInfo.carrier.name', 'qoeContentId', 'redirectUrl', 'fragments', 'userEvents'], axis=1)
# df.to_pickle('../data/droped_all_1.pkl')

# %%
# df = pd.read_pickle('../centos/data/droped_all.pkl')
df.shape
# Out:
# (25049, 25)

# %% [markdown]
# ## Label Encoding - Device

# %%
df['device'].value_counts()
# Out:
# Android 8.0.0    14456
# Android 8.1.0     2762
# Android 5.0.2     2059
# Android 7.0       1109
# Android 7.1.1      829
# Android 7.1.2      790
# Android 6.0.1      771
# Android 5.0        344
# Android 5.1.1      330
# Android 5.0.1      225
# Android 6.0        119
# Android 9           50
# Android 5.1          7
# Name: device, dtype: int64

# %%
le_divice = preprocessing.LabelEncoder()
df['device'] = le_divice.fit_transform(df['device'].astype(str))
le_divice.classes_
# Out:
# array(['Android 5.0', 'Android 5.0.1', 'Android 5.0.2', 'Android 5.1',
#        'Android 5.1.1', 'Android 6.0', 'Android 6.0.1', 'Android 7.0',
#        'Android 7.1.1', 'Android 7.1.2', 'Android 8.0.0', 'Android 8.1.0',
#        'Android 9', 'nan'], dtype=object)

# %%
df['device'].head()
# Out:
# 0     7
# 1    10
# 2    10
# 3    10
# 4    10
# Name: device, dtype: int64

# %% [markdown]
# ## Label Encoding - NetworkType

# %%
df['networkInfo.type'].value_counts()
# Out:
# WiFi    17098
# LTE      6593
# 3G        157
# Name: networkInfo.type, dtype: int64

# %%
le_network = preprocessing.LabelEncoder()
df['networkInfo.type'] = le_network.fit_transform(df['networkInfo.type'].astype(str))
le_network.classes_
# Out:
# array(['3G', 'LTE', 'WiFi', 'nan'], dtype=object)

# %%
df['networkInfo.type'].head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    2
# 4    2
# Name: networkInfo.type, dtype: int64

# %%
df.shape
# Out:
# (25049, 25)

# %% [markdown]
# ## Label Encoding - DRM system

# %%
le_drm = preprocessing.LabelEncoder()
df['licenseInfo.drmSystem'] = le_drm.fit_transform(df['licenseInfo.drmSystem'].astype(str))
le_drm.classes_
# Out:
# array(['edef8ba9-79d6-4ace-a3c8-27dcd51d21ed', 'nan'], dtype=object)

# %%
df['licenseInfo.drmSystem'].value_counts()
# Out:
# 0    21309
# 1     3740
# Name: licenseInfo.drmSystem, dtype: int64

# %% [markdown]
# ## Counting Data - FrameDropped

# %%
for row, val in enumerate(df['frameDropped']):
    if isinstance(val, float):
        df['frameDropped'][row] = 0
    else:
        df['frameDropped'][row] = len(val)
        
    if row%100 == 0:
        print(row)
# Out:
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 0
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000

# %%
df['frameDropped'].value_counts()
# Out:
# 0     24500
# 1       465
# 2        48
# 3        17
# 6         5
# 4         5
# 9         4
# 5         2
# 11        1
# 10        1
# 7         1
# Name: frameDropped, dtype: int64

# %% [markdown]
# ## Counting Data - QualityChanged

# %%
df['qualityChangedCount'] = None

# %%
for row, val in enumerate(df['qualityChanged']):
    if isinstance(val, float):
        df['qualityChangedCount'][row] = 0
    else:
        df['qualityChangedCount'][row] = len(val)
        
    if row%100 == 0:
        print(row)
# Out:
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 0
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21100
# 21200
# 21300
# 21400
# 21500
# 21600
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800
# 23900
# 24000
# 24100
# 24200
# 24300
# 24400
# 24500
# 24600
# 24700
# 24800
# 24900
# 25000

# %%
df['qualityChangedCount'].value_counts()
# Out:
# 0    14020
# 1     5915
# 2     5001
# 3       71
# 4       38
# 5        3
# 6        1
# Name: qualityChangedCount, dtype: int64

# %%
df
# Out:
#       avgDecodingTime bufferedDuration  \
# 0                   0              441
# 1                   3                0
# 2                   0               59
# 3                   5               39
# 4                   0               33
# 5                   0               22
# 6                   0               31
# 7                   1               51
# 8                   0               64
# 9                   0                0
# 10                  0               60
# 11                  1                4
# 12                  9               59
# 13                  0               57
# 14                  0                0
# 15                  0               42
# 16                  0               47
# 17                  1               50
# 18                  0               48
# 19                  0               51
# 20                  0               19
# 21                 12                0
# 22                  0                4
# 23                  1               49
# 24                  0               58
# 25                  0              324
# 26                  0                0
# 27                  5                0
# 28                  0             2576
# 29                  0               52
# ...               ...              ...
# 25019               0                0
# 25020               0               58
# 25021               4               36
# 25022               0               34
# 25023               0               55
# 25024               0               -1
# 25025               0               -1
# 25026               0               44
# 25027               0                0
# 25028               0               -1
# 25029               0               57
# 25030               0                0
# 25031               0               51
# 25032             NaN              NaN
# 25033               4                0
# 25034               0               13
# 25035               1               28
# 25036               5               51
# 25037               0               33
# 25038               0               55
# 25039               0               46
# 25040               0                0
# 25041               0               34
# 25042               1             2563
# 25043               7               35
# 25044               0               31
# 25045               0               31
# 25046               0               53
# 25047               4               24
# 25048               8               51
#
#                                               bufferings  \
# 0      [{'currentTime': 1541470583, 'duration': 146},...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4      [{'currentTime': 1541471265, 'duration': 28}, ...
# 5                                                     []
# 6                                                     []
# 7                                                     []
# 8                                                     []
# 9                                                     []
# 10                                                    []
# 11        [{'currentTime': 1541470859, 'duration': 922}]
# 12                                                    []
# 13                                                    []
# 14                                                    []
# 15                                                    []
# 16        [{'currentTime': 1541470803, 'duration': 128}]
# 17        [{'currentTime': 1541470815, 'duration': 335}]
# 18                                                    []
# 19                                                    []
# 20                                                    []
# 21                                                    []
# 22                                                    []
# 23     [{'currentTime': 1541470473, 'duration': 134},...
# 24                                                    []
# 25     [{'currentTime': 1541470507, 'duration': 237},...
# 26                                                    []
# 27     [{'currentTime': 1541470515, 'duration': 386},...
# 28                                                    []
# 29                                                    []
# ...                                                  ...
# 25019                                                 []
# 25020                                                 []
# 25021  [{'currentTime': 1541634792, 'duration': 603},...
# 25022                                                 []
# 25023                                                 []
# 25024                                                 []
# 25025                                                 []
# 25026                                                 []
# 25027                                                 []
# 25028                                                 []
# 25029                                                 []
# 25030                                                 []
# 25031                                                 []
# 25032                                                NaN
# 25033                                                 []
# 25034      [{'currentTime': 1541634830, 'duration': 76}]
# 25035      [{'currentTime': 1541634885, 'duration': 49}]
# 25036     [{'currentTime': 1541634884, 'duration': 674}]
# 25037                                                 []
# 25038                                                 []
# 25039                                                 []
# 25040                                                 []
# 25041                                                 []
# 25042  [{'currentTime': 1541635060, 'duration': 110},...
# 25043                                                 []
# 25044                                                 []
# 25045                                                 []
# 25046                                                 []
# 25047     [{'currentTime': 1541635089, 'duration': 449}]
# 25048                                                 []
#
#                                               contentUrl currentPosition  \
# 0      http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 1      http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.58277e+06
# 2      http://abc-streaming.akamaized.net/g/mpd/d/mai...     6.44276e+06
# 3      http://abc-streaming.akamaized.net/g/mpd/d/mai...      2.5053e+06
# 4      http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.44438e+06
# 5      http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 6      http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.54378e+06
# 7      http://abc-streaming.akamaized.net/g/mpd/d/mai...          415680
# 8      http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 9      http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 10     http://abc-streaming.akamaized.net/g/mpd/d/mai...          182133
# 11     http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.13812e+06
# 12     http://abc-streaming.akamaized.net/g/mpd/d/mai...          817022
# 13     http://abc-streaming.akamaized.net/g/mpd/d/mai...          116737
# 14     http://abc-streaming.akamaized.net/g/mpd/d/mai...     1.27542e+06
# 15     http://abc-streaming.akamaized.net/g/mpd/d/mai...     7.54090e+06
# 16     http://abc-streaming.akamaized.net/g/mpd/d/mai...           16165
# 17     http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 18     http://abc-streaming.akamaized.net/g/mpd/d/mai...     4.58798e+06
# 19     /storage/emulated/0/Movies/dmktvs/contents/105...     1.97896e+06
# 20     /storage/emulated/0/Movies/dmktvs/contents/110...     2.56227e+06
# 21     http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.71001e+06
# 22     http://abc-streaming.akamaized.net/g/mpd/d/mai...     4.16398e+06
# 23     http://abc-streaming.akamaized.net/g/mpd/d/mai...            2937
# 24     http://abc-streaming.akamaized.net/g/mpd/d/mai...     3.33644e+06
# 25     http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 26     http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 27     http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.61003e+06
# 28     http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 29     http://abc-streaming.akamaized.net/g/mpd/d/mai...            9374
# ...                                                  ...             ...
# 25019  http://abc-streaming.akamaized.net/g/mpd/d/mai...      2.4709e+06
# 25020  http://abc-streaming.akamaized.net/g/mpd/d/mai...      3.3239e+06
# 25021  http://abc-streaming.akamaized.net/g/mpd/d/mai...      2.5303e+06
# 25022  http://abc-streaming.akamaized.net/g/mpd/d/mai...     6.73225e+06
# 25023  http://abc-streaming.akamaized.net/g/mpd/d/mai...            6886
# 25024  /storage/emulated/0/Movies/dmktvs/contents/107...              -1
# 25025                                                NaN              -1
# 25026  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.89607e+06
# 25027  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.60296e+06
# 25028  /storage/emulated/0/Movies/dmktvs/contents/109...              -1
# 25029  http://abc-streaming.akamaized.net/g/mpd/d/mai...     1.22561e+06
# 25030  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.56796e+06
# 25031  http://abc-streaming.akamaized.net/g/mpd/d/mai...          467260
# 25032  http://abc-streaming.akamaized.net/g/mpd/d/mai...             NaN
# 25033  http://abc-streaming.akamaized.net/g/mpd/d/mai...     1.35394e+06
# 25034  http://abc-streaming.akamaized.net/g/mpd/d/mai...             160
# 25035  http://abc-streaming.akamaized.net/g/mpd/d/mai...              20
# 25036  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.54682e+06
# 25037  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.55743e+06
# 25038  http://abc-streaming.akamaized.net/g/mpd/d/mai...          320660
# 25039  http://abc-streaming.akamaized.net/g/mpd/d/mai...     5.22706e+06
# 25040  http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 25041  http://abc-streaming.akamaized.net/g/mpd/d/mai...          218085
# 25042  http://abc-streaming.akamaized.net/g/mpd/d/mai...               0
# 25043  http://abc-streaming.akamaized.net/g/mpd/d/mai...      2.5924e+06
# 25044  http://abc-streaming.akamaized.net/g/mpd/d/mai...          504848
# 25045  /storage/emulated/0/Movies/dmktvs/contents/108...     1.15132e+06
# 25046  http://abc-streaming.akamaized.net/g/mpd/d/mai...     1.66277e+06
# 25047  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.51559e+06
# 25048  http://abc-streaming.akamaized.net/g/mpd/d/mai...     2.50515e+06
#
#        device errorCode                                        errorString  \
# 0           7         0                                                NaN
# 1          10         0                                                NaN
# 2          10         0                                                NaN
# 3          10         0                                                NaN
# 4          10         0                                                NaN
# 5           4       -38  com.google.android.exoplayer2.ExoPlaybackExcep...
# 6          10         0                                                NaN
# 7          10         0                                                NaN
# 8          10         0                                                NaN
# 9           9         0                                                NaN
# 10         10         0                                                NaN
# 11         10         0                                                NaN
# 12         10         0                                                NaN
# 13         10         0                                                NaN
# 14         10         0                                                NaN
# 15         10         0                                                NaN
# 16          9         0                                                NaN
# 17          9         0                                                NaN
# 18         10         0                                                NaN
# 19         11         0                                                NaN
# 20          2         0                                                NaN
# 21         10         0                                                NaN
# 22         10         0                                                NaN
# 23         10         0                                                NaN
# 24         10         0                                                NaN
# 25          8         0                                                NaN
# 26         10         0                                                NaN
# 27         10         0                                                NaN
# 28         10         0                                                NaN
# 29         11         0                                                NaN
# ...       ...       ...                                                ...
# 25019      10         0                                                NaN
# 25020       2         0                                                NaN
# 25021      10         0                                                NaN
# 25022      10         0                                                NaN
# 25023       2         0                                                NaN
# 25024      10   -100702  com.google.android.exoplayer2.ExoPlaybackExcep...
# 25025      13   -100702  com.google.android.exoplayer2.ExoPlaybackExcep...
# 25026      10         0                                                NaN
# 25027      10         0                                                NaN
# 25028      10   -100702  com.google.android.exoplayer2.ExoPlaybackExcep...
# 25029      10         0                                                NaN
# 25030       2         0                                                NaN
# 25031      10         0                                                NaN
# 25032       2         0                                                NaN
# 25033       7         0                                                NaN
# 25034       7         0                                                NaN
# 25035      10         0                                                NaN
# 25036      10         0                                                NaN
# 25037       2         0                                                NaN
# 25038      10         0                                                NaN
# 25039      10         0                                                NaN
# 25040      11         0                                                NaN
# 25041      10         0                                                NaN
# 25042       0         0                                                NaN
# 25043      10         0                                                NaN
# 25044      10         0                                                NaN
# 25045      10         0                                                NaN
# 25046       0         0                                                NaN
# 25047      10         0                                                NaN
# 25048      10         0                                                NaN
#
#       estimatedBandwidth fragmentSum.bitrate         ...          \
# 0             6.1251e+07         8.26407e+07         ...
# 1            1.75141e+07                   0         ...
# 2            1.05965e+07         1.47859e+07         ...
# 3            1.72048e+07                   0         ...
# 4            3.30116e+07         6.94974e+07         ...
# 5            1.57697e+08         2.48399e+07         ...
# 6            4.60662e+07                   0         ...
# 7            2.99102e+07         3.97736e+07         ...
# 8            8.62791e+07                   0         ...
# 9            1.90631e+07         2.61467e+07         ...
# 10           5.15626e+07         5.66065e+07         ...
# 11           1.34584e+07         3.41411e+07         ...
# 12           4.99233e+07         2.37038e+07         ...
# 13           1.37773e+07         2.52974e+07         ...
# 14            6.2943e+07         1.18842e+07         ...
# 15           4.57235e+07                   0         ...
# 16           5.09466e+07                   0         ...
# 17           1.62363e+07         3.50994e+07         ...
# 18           3.01589e+07                   0         ...
# 19           1.04205e+08                   0         ...
# 20           8.99987e+07                   0         ...
# 21           6.67914e+07                   0         ...
# 22           4.02846e+07         6.25546e+06         ...
# 23           8.07158e+07         1.06455e+08         ...
# 24           4.95297e+07                   0         ...
# 25           3.85324e+07         5.86669e+07         ...
# 26           7.45788e+07                   0         ...
# 27            1.0483e+08                   0         ...
# 28           1.91675e+07                   0         ...
# 29           7.19628e+06         1.33807e+07         ...
# ...                  ...                 ...         ...
# 25019         3.9925e+07                   0         ...
# 25020        5.05247e+07                   0         ...
# 25021        1.44459e+07         1.23813e+07         ...
# 25022         5.6051e+07                   0         ...
# 25023        3.05945e+07                   0         ...
# 25024                 -1                   0         ...
# 25025                 -1         1.43678e+07         ...
# 25026        1.52022e+08                   0         ...
# 25027        2.86608e+07                   0         ...
# 25028                 -1                   0         ...
# 25029        4.08866e+07                   0         ...
# 25030        3.15282e+07                   0         ...
# 25031        7.60118e+06         5.92889e+06         ...
# 25032                NaN                 NaN         ...
# 25033        3.60654e+07                   0         ...
# 25034        2.13089e+07         1.13581e+07         ...
# 25035        5.42945e+07         3.45263e+07         ...
# 25036        7.73872e+07         9.27423e+07         ...
# 25037        3.50276e+07                   0         ...
# 25038        2.93862e+07                   0         ...
# 25039        1.34616e+07                   0         ...
# 25040        3.77246e+07                   0         ...
# 25041        2.60204e+07                   0         ...
# 25042        2.77248e+07         2.34661e+07         ...
# 25043        1.15722e+07         1.43841e+07         ...
# 25044         4.6549e+07                   0         ...
# 25045        2.44091e+08                   0         ...
# 25046         2.5275e+07                   0         ...
# 25047        1.33984e+08         7.94886e+07         ...
# 25048        4.14051e+07                   0         ...
#
#       licenseInfo.elapsedTime maxDecodingTime networkErrors  \
# 0                         703              19             0
# 1                         888              24             0
# 2                         913               1             0
# 3                         939               8            10
# 4                         851               2             0
# 5                        1105               0             0
# 6                         867               0             0
# 7                         708              15             0
# 8                         823              16             0
# 9                        1670               0             0
# 10                        878               1             0
# 11                        876               8             0
# 12                        884              17             0
# 13                       2033              25             0
# 14                        904               0             0
# 15                        830               2             0
# 16                       1175               4             0
# 17                       1170               6             0
# 18                       1217               0             0
# 19                        910               0             0
# 20                       1284               0             0
# 21                        793              22             0
# 22                       1432               0             0
# 23                        711              22             0
# 24                        965               0             0
# 25                        969              11             0
# 26                        840               0             0
# 27                        892              13             0
# 28                        962               0             0
# 29                       1004               3             0
# ...                       ...             ...           ...
# 25019                     978               5             0
# 25020                     825               0             0
# 25021                     682               8             0
# 25022                     626               0             0
# 25023                    1011               0             0
# 25024                     973               0             0
# 25025                     NaN               0             0
# 25026                    1038               0             0
# 25027                     722               1             0
# 25028                     777               0             0
# 25029                     865               1             0
# 25030                     870               0             0
# 25031                     763               0             0
# 25032                     912             NaN           NaN
# 25033                    1487               6             0
# 25034                    1460               1             0
# 25035                     725               7             0
# 25036                     619              19             0
# 25037                    1015               6             0
# 25038                    1173               0             0
# 25039                     859               0             0
# 25040                     872               0             0
# 25041                     992               0             0
# 25042                     892              10             0
# 25043                     810              16             0
# 25044                     784               0             0
# 25045                    1571               0             0
# 25046                     838               9             0
# 25047                     917              10             0
# 25048                    1087              13             0
#
#       networkInfo.carrier.mnc networkInfo.type     position  \
# 0                         NaN                2            0
# 1                          10                2  2.58277e+06
# 2                          10                1  6.44276e+06
# 3                          10                2   2.5053e+06
# 4                          10                2  2.44438e+06
# 5                         NaN                2            0
# 6                          10                2  2.54378e+06
# 7                          10                2       415680
# 8                          51                2            0
# 9                          10                2            0
# 10                         10                2       182133
# 11                         10                2  2.13812e+06
# 12                         10                1       817022
# 13                         10                1       116737
# 14                         10                1  1.27542e+06
# 15                         10                2  7.54090e+06
# 16                         10                1        16165
# 17                         10                1            0
# 18                         10                1  4.58798e+06
# 19                         10                1  1.97896e+06
# 20                         50                2  2.56227e+06
# 21                         51                2  2.71001e+06
# 22                         10                1  4.16398e+06
# 23                         10                2         2937
# 24                         10                1  3.33644e+06
# 25                         10                2            0
# 26                         10                2            0
# 27                         10                2  2.61003e+06
# 28                         10                2            0
# 29                         10                1         9374
# ...                       ...              ...          ...
# 25019                      10                2   2.4709e+06
# 25020                      10                2   3.3239e+06
# 25021                      10                1   2.5303e+06
# 25022                      51                2  6.73225e+06
# 25023                     NaN                2         6886
# 25024                      10                2            0
# 25025                     NaN                3            0
# 25026                      20                2  2.89607e+06
# 25027                      10                2  2.60296e+06
# 25028                      10                1            0
# 25029                      10                1  1.22561e+06
# 25030                      10                2  2.56796e+06
# 25031                      10                2       467260
# 25032                     NaN                2           46
# 25033                      10                2  1.35394e+06
# 25034                      10                2          160
# 25035                      10                2           20
# 25036                      10                2  2.54682e+06
# 25037                      10                1  2.55743e+06
# 25038                      10                2       320660
# 25039                      10                1  5.22706e+06
# 25040                      10                2            0
# 25041                     NaN                2       218085
# 25042                      10                1            0
# 25043                      20                2   2.5924e+06
# 25044                      10                2       504848
# 25045                      10                1  1.15132e+06
# 25046                      10                2  1.66277e+06
# 25047                      10                2  2.51559e+06
# 25048                      51                2  2.50515e+06
#
#                                           qualityChanged       sessionId  \
# 0      [{'bandwidth': 429745, 'timestamp': 1541470582...  43754809210075
# 1                                                     []   9556708911304
# 2      [{'bandwidth': 1343060, 'timestamp': 154147065...  40367776409166
# 3                                                     []  64388793530698
# 4      [{'bandwidth': 427182, 'timestamp': 1541471263...  66221138236843
# 5      [{'bandwidth': 425380, 'timestamp': 1541471284...  71636362340456
# 6                                                     []   1557863053824
# 7      [{'bandwidth': 2706022, 'timestamp': 154147055...  39705373231354
# 8                                                     []  51006791020667
# 9      [{'bandwidth': 431304, 'timestamp': 1541470779...  45090001602356
# 10     [{'bandwidth': 2697098, 'timestamp': 154147078...  13535622710485
# 11     [{'bandwidth': 2721046, 'timestamp': 154147085...  26232845244139
# 12     [{'bandwidth': 1348258, 'timestamp': 154147085...  44184914898941
# 13     [{'bandwidth': 1354857, 'timestamp': 154147087...  79686275917662
# 14     [{'bandwidth': 426814, 'timestamp': 1541470870...  69377113371712
# 15                                                    []   9784829299392
# 16                                                    []  22203003221385
# 17     [{'bandwidth': 442226, 'timestamp': 1541470811...  86022459397083
# 18                                                    []   8924415312536
# 19                                                    []  19454236950026
# 20                                                    []   1254714794004
# 21                                                    []  74436387634018
# 22     [{'bandwidth': 248164, 'timestamp': 1541470474...  52935778324706
# 23     [{'bandwidth': 434127, 'timestamp': 1541470471...  40848322841638
# 24                                                    []  63521418981190
# 25     [{'bandwidth': 432617, 'timestamp': 1541470505...  30367644639321
# 26                                                    []  26386688652978
# 27                                                    []  57367881028460
# 28                                                    []  79685498024563
# 29     [{'bandwidth': 1353515, 'timestamp': 154147054...  87065573136466
# ...                                                  ...             ...
# 25019                                                 []  48551444191402
# 25020                                                 []  95635190681602
# 25021  [{'bandwidth': 251836, 'timestamp': 1541634792...  45529291810235
# 25022                                                 []  38733001010494
# 25023                                                 []  35003819185434
# 25024  [{'bandwidth': 430577, 'timestamp': 1541634939...  83468516730110
# 25025  [{'bandwidth': 443873, 'timestamp': 1541634940...  47394205555844
# 25026                                                 []  54219036033331
# 25027                                                 []   1802300260209
# 25028  [{'bandwidth': 424935, 'timestamp': 1541635034...  82574664244755
# 25029                                                 []  77784351711978
# 25030                                                 []   3767389767600
# 25031  [{'bandwidth': 2831194, 'timestamp': 154163487...  97122309562469
# 25032                                                NaN  51849721376554
# 25033                                                 []  79229539546345
# 25034  [{'bandwidth': 424191, 'timestamp': 1541634828...  25228752583485
# 25035  [{'bandwidth': 429215, 'timestamp': 1541634883...  90027401034766
# 25036  [{'bandwidth': 424738, 'timestamp': 1541634882...   2947211092648
# 25037                                                 []  83749986195030
# 25038                                                 []   9584906658372
# 25039                                                 []  17378919226266
# 25040                                                 []  16735893580720
# 25041                                                 []  50595742977362
# 25042  [{'bandwidth': 425779, 'timestamp': 1541635058...   6325122305173
# 25043  [{'bandwidth': 2741229, 'timestamp': 154163505...  47959143798735
# 25044                                                 []  30195195296550
# 25045                                                 []  65216069943157
# 25046                                                 []  48644683623098
# 25047  [{'bandwidth': 427001, 'timestamp': 1541635088...  13848651531364
# 25048                                                 []   2804611568134
#
#         timestamp qualityChangedCount
# 0      1541470586                   2
# 1      1541470588                   0
# 2      1541470657                   1
# 3      1541470656                   0
# 4      1541471274                   2
# 5      1541471286                   2
# 6      1541470555                   0
# 7      1541470561                   1
# 8      1541470780                   0
# 9      1541470785                   2
# 10     1541470787                   1
# 11     1541470861                   1
# 12     1541470860                   1
# 13     1541470880                   1
# 14     1541470872                   2
# 15     1541470760                   0
# 16     1541470810                   0
# 17     1541470817                   2
# 18     1541470454                   0
# 19     1541470494                   0
# 20     1541470504                   0
# 21     1541470443                   0
# 22     1541470477                   1
# 23     1541470477                   2
# 24     1541470480                   0
# 25     1541470511                   2
# 26     1541470517                   0
# 27     1541470521                   0
# 28     1541470545                   0
# 29     1541470549                   1
# ...           ...                 ...
# 25019  1541634701                   0
# 25020  1541634706                   0
# 25021  1541634795                   1
# 25022  1541634811                   0
# 25023  1541634817                   0
# 25024  1541634940                   1
# 25025  1541634941                   2
# 25026  1541635026                   0
# 25027  1541635029                   0
# 25028  1541635035                   1
# 25029  1541635047                   0
# 25030  1541635047                   0
# 25031  1541634878                   1
# 25032  1541634823                   0
# 25033  1541634823                   0
# 25034  1541634831                   2
# 25035  1541634885                   2
# 25036  1541634886                   2
# 25037  1541634855                   0
# 25038  1541634778                   0
# 25039  1541634784                   0
# 25040  1541634785                   0
# 25041  1541635051                   0
# 25042  1541635062                   2
# 25043  1541635057                   1
# 25044  1541635131                   0
# 25045  1541635135                   0
# 25046  1541634965                   0
# 25047  1541635097                   2
# 25048  1541635111                   0
#
# [25049 rows x 26 columns]

# %% [markdown]
# ## ContentUrl -> Content type

# %%
df['content_type'] = ''

# %%
for i in range(0,len(df)):
    try: 
        if 'video' in df['contentUrl'][i].split('/'):
            df['content_type'][i] = 'video'
        elif 'audio' in df['contentUrl'][i].split('/'):
            df['content_type'][i] = 'audio'
        else : 
            df['content_type'][i] = 'contents'
    except:
        df['content_type'][i] = 'nothing'
        pass
    
    if row%100 == 0:
        print(row)
# Out:
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df = df[df['content_type'] != 'nothing']

# %%
le_content = preprocessing.LabelEncoder()

df['content_type'] = le_content.fit_transform(df['content_type'].astype(str))
le_content.classes_
## 이거 돌리고 확인!! 18.12.19
# Out:
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# array(['contents', 'video'], dtype=object)

# %%
df['content_type'].value_counts()
# Out:
# 1    19338
# 0     4513
# Name: content_type, dtype: int64

# %%
del df['contentUrl']

# %% [markdown]
# ## bufferings -> bufferingTime ( total buffering time)

# %%
df['bufferingTime']= 0
# Out:
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
for row, val in enumerate(df['bufferings']):
    if isinstance(val, float):
        df['bufferingTime'].iloc[row] = 0
    else:
        if len(df.bufferings.iloc[row])!=0:
            for i in range(len(df.bufferings.iloc[row])):
                df['bufferingTime'].iloc[row] += df.iloc[row]['bufferings'][i]['duration']
        else:
            df['bufferingTime'].iloc[row]= 0
    
    if row%100 == 0:
        print(row)
# Out:
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# 0
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/centos/anaconda3/envs/dev/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# 13900
# 14000
# 14100
# 14200
# 14300
# 14400
# 14500
# 14600
# 14700
# 14800
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# 15700
# 15800
# 15900
# 16000
# 16100
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# 16800
# 16900
# 17000
# 17100
# 17200
# 17300
# 17400
# 17500
# 17600
# 17700
# 17800
# 17900
# 18000
# 18100
# 18200
# 18300
# 18400
# 18500
# 18600
# 18700
# 18800
# 18900
# 19000
# 19100
# 19200
# 19300
# 19400
# 19500
# 19600
# 19700
# 19800
# 19900
# 20000
# 20100
# 20200
# 20300
# 20400
# 20500
# 20600
# 20700
# 20800
# 20900
# 21000
# 21700
# 21800
# 21900
# 22000
# 22100
# 22200
# 22300
# 22400
# 22500
# 22600
# 22700
# 22800
# 22900
# 23000
# 23100
# 23200
# 23300
# 23400
# 23500
# 23600
# 23700
# 23800

# %%
del df['bufferings']

# %%
del df['qualityChanged']

# %%
del df['errorString']

# %%
df.to_pickle('../data/processed_all_v1_1.pkl')
