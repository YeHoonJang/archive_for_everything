# %%
n = int(input())
numbers = list(map(int, input().split()))
arithmetics = list(map(int, input().split()))

# results = get_max_min(n, numbers, arithmetics)
# Out:
# 6
# 1 2 3 4 5 6
# 2 1 1 1

# %%
# numbers = [1, 2, 3, 4]
# arithmetics = [1, 0, 1, 1]
print(numbers)

print(arithmetics)
# Out:
# [1, 2, 3, 4, 5, 6]
# [2, 1, 1, 1]

# %%
def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return int(a / b)

# %%
operators = {0: "add ", 1: "sub ", 2: "mul ", 3: "div "}

# %%
# def generate_operators_list(operator, number_of_operator):
#     operators_str = ""
#     for idx in range(len(arithmetics)):
#     if arithmetics[idx] != 0:
#         operators_str += operators[idx]*arithmetics[idx]

# %%
operators_str = ""
for idx in range(len(arithmetics)):
    if arithmetics[idx] != 0:
        operators_str += operators[idx]*arithmetics[idx]
    
        
operators_str.strip()
# Out:
# 'add add sub mul div'

# %%
from itertools import permutations

operators_permutation = permutations(operators_str.strip().split(" "), len(operators_str.strip().split(" ")) )
set_permutation = list(set(operators_permutation))
set_permutation
# Out:
# [('add', 'div', 'add', 'sub', 'mul'),
#  ('add', 'div', 'sub', 'add', 'mul'),
#  ('mul', 'add', 'add', 'div', 'sub'),
#  ('mul', 'add', 'div', 'add', 'sub'),
#  ('div', 'add', 'add', 'mul', 'sub'),
#  ('div', 'add', 'mul', 'add', 'sub'),
#  ('add', 'add', 'sub', 'mul', 'div'),
#  ('add', 'add', 'mul', 'sub', 'div'),
#  ('add', 'mul', 'sub', 'div', 'add'),
#  ('add', 'mul', 'div', 'sub', 'add'),
#  ('sub', 'add', 'mul', 'div', 'add'),
#  ('sub', 'add', 'div', 'mul', 'add'),
#  ('sub', 'div', 'add', 'mul', 'add'),
#  ('sub', 'div', 'mul', 'add', 'add'),
#  ('mul', 'add', 'sub', 'div', 'add'),
#  ('mul', 'add', 'div', 'sub', 'add'),
#  ('add', 'mul', 'add', 'div', 'sub'),
#  ('add', 'mul', 'div', 'add', 'sub'),
#  ('sub', 'mul', 'add', 'add', 'div'),
#  ('mul', 'sub', 'add', 'div', 'add'),
#  ('mul', 'sub', 'div', 'add', 'add'),
#  ('add', 'sub', 'mul', 'div', 'add'),
#  ('add', 'sub', 'div', 'mul', 'add'),
#  ('mul', 'sub', 'add', 'add', 'div'),
#  ('sub', 'mul', 'add', 'div', 'add'),
#  ('sub', 'mul', 'div', 'add', 'add'),
#  ('add', 'div', 'sub', 'mul', 'add'),
#  ('add', 'div', 'mul', 'sub', 'add'),
#  ('div', 'sub', 'add', 'add', 'mul'),
#  ('div', 'add', 'add', 'sub', 'mul'),
#  ('div', 'add', 'sub', 'add', 'mul'),
#  ('add', 'add', 'div', 'mul', 'sub'),
#  ('add', 'add', 'mul', 'div', 'sub'),
#  ('mul', 'div', 'add', 'add', 'sub'),
#  ('div', 'add', 'mul', 'sub', 'add'),
#  ('add', 'div', 'add', 'mul', 'sub'),
#  ('add', 'div', 'mul', 'add', 'sub'),
#  ('add', 'add', 'div', 'sub', 'mul'),
#  ('add', 'add', 'sub', 'div', 'mul'),
#  ('mul', 'add', 'add', 'sub', 'div'),
#  ('mul', 'add', 'sub', 'add', 'div'),
#  ('div', 'mul', 'add', 'sub', 'add'),
#  ('div', 'mul', 'sub', 'add', 'add'),
#  ('sub', 'add', 'add', 'div', 'mul'),
#  ('sub', 'add', 'div', 'add', 'mul'),
#  ('add', 'mul', 'sub', 'add', 'div'),
#  ('add', 'mul', 'add', 'sub', 'div'),
#  ('sub', 'div', 'add', 'add', 'mul'),
#  ('mul', 'div', 'add', 'sub', 'add'),
#  ('mul', 'div', 'sub', 'add', 'add'),
#  ('div', 'mul', 'add', 'add', 'sub'),
#  ('div', 'sub', 'mul', 'add', 'add'),
#  ('sub', 'add', 'add', 'mul', 'div'),
#  ('sub', 'add', 'mul', 'add', 'div'),
#  ('add', 'sub', 'add', 'div', 'mul'),
#  ('add', 'sub', 'div', 'add', 'mul'),
#  ('add', 'sub', 'add', 'mul', 'div'),
#  ('add', 'sub', 'mul', 'add', 'div'),
#  ('div', 'sub', 'add', 'mul', 'add'),
#  ('div', 'add', 'sub', 'mul', 'add')]

# %%
len(set_permutation)
# Out:
# 60

# %%
operator_func = {"add": add, "sub": sub, 
                 "mul": mul, "div": div}
real = []

for idx_1 in range(len(set_permutation)):
    result_list = []
    result_list.append(numbers[0])
    print("--------------------------------")
    for idx_2 in range(len(set_permutation[idx_1])):
        operator_idx = set_permutation[idx_1][idx_2]
        print(operator_idx)

        result_list.append(operator_func[operator_idx](result_list[idx_2], numbers[idx_2 +1]))
        print("#1:", result_list[idx_2], " / #2:", numbers[idx_2 +1] ,"/ result: ", result_list[idx_2+1])
    real.append(result_list[-1])

real
# Out:
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# div
# #1: 3  / #2: 3 / result:  1
# add
# #1: 1  / #2: 4 / result:  5
# sub
# #1: 5  / #2: 5 / result:  0
# mul
# #1: 0  / #2: 6 / result:  0
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# div
# #1: 3  / #2: 3 / result:  1
# sub
# #1: 1  / #2: 4 / result:  -3
# add
# #1: -3  / #2: 5 / result:  2
# mul
# #1: 2  / #2: 6 / result:  12
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# add
# #1: 2  / #2: 3 / result:  5
# add
# #1: 5  / #2: 4 / result:  9
# div
# #1: 9  / #2: 5 / result:  1
# sub
# #1: 1  / #2: 6 / result:  -5
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# add
# #1: 2  / #2: 3 / result:  5
# div
# #1: 5  / #2: 4 / result:  1
# add
# #1: 1  / #2: 5 / result:  6
# sub
# #1: 6  / #2: 6 / result:  0
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# add
# #1: 0  / #2: 3 / result:  3
# add
# #1: 3  / #2: 4 / result:  7
# mul
# #1: 7  / #2: 5 / result:  35
# sub
# #1: 35  / #2: 6 / result:  29
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# add
# #1: 0  / #2: 3 / result:  3
# mul
# #1: 3  / #2: 4 / result:  12
# add
# #1: 12  / #2: 5 / result:  17
# sub
# #1: 17  / #2: 6 / result:  11
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# add
# #1: 3  / #2: 3 / result:  6
# sub
# #1: 6  / #2: 4 / result:  2
# mul
# #1: 2  / #2: 5 / result:  10
# div
# #1: 10  / #2: 6 / result:  1
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# add
# #1: 3  / #2: 3 / result:  6
# mul
# #1: 6  / #2: 4 / result:  24
# sub
# #1: 24  / #2: 5 / result:  19
# div
# #1: 19  / #2: 6 / result:  3
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# mul
# #1: 3  / #2: 3 / result:  9
# sub
# #1: 9  / #2: 4 / result:  5
# div
# #1: 5  / #2: 5 / result:  1
# add
# #1: 1  / #2: 6 / result:  7
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# mul
# #1: 3  / #2: 3 / result:  9
# div
# #1: 9  / #2: 4 / result:  2
# sub
# #1: 2  / #2: 5 / result:  -3
# add
# #1: -3  / #2: 6 / result:  3
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# add
# #1: -1  / #2: 3 / result:  2
# mul
# #1: 2  / #2: 4 / result:  8
# div
# #1: 8  / #2: 5 / result:  1
# add
# #1: 1  / #2: 6 / result:  7
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# add
# #1: -1  / #2: 3 / result:  2
# div
# #1: 2  / #2: 4 / result:  0
# mul
# #1: 0  / #2: 5 / result:  0
# add
# #1: 0  / #2: 6 / result:  6
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# div
# #1: -1  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# mul
# #1: 4  / #2: 5 / result:  20
# add
# #1: 20  / #2: 6 / result:  26
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# div
# #1: -1  / #2: 3 / result:  0
# mul
# #1: 0  / #2: 4 / result:  0
# add
# #1: 0  / #2: 5 / result:  5
# add
# #1: 5  / #2: 6 / result:  11
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# add
# #1: 2  / #2: 3 / result:  5
# sub
# #1: 5  / #2: 4 / result:  1
# div
# #1: 1  / #2: 5 / result:  0
# add
# #1: 0  / #2: 6 / result:  6
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# add
# #1: 2  / #2: 3 / result:  5
# div
# #1: 5  / #2: 4 / result:  1
# sub
# #1: 1  / #2: 5 / result:  -4
# add
# #1: -4  / #2: 6 / result:  2
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# mul
# #1: 3  / #2: 3 / result:  9
# add
# #1: 9  / #2: 4 / result:  13
# div
# #1: 13  / #2: 5 / result:  2
# sub
# #1: 2  / #2: 6 / result:  -4
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# mul
# #1: 3  / #2: 3 / result:  9
# div
# #1: 9  / #2: 4 / result:  2
# add
# #1: 2  / #2: 5 / result:  7
# sub
# #1: 7  / #2: 6 / result:  1
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# mul
# #1: -1  / #2: 3 / result:  -3
# add
# #1: -3  / #2: 4 / result:  1
# add
# #1: 1  / #2: 5 / result:  6
# div
# #1: 6  / #2: 6 / result:  1
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# sub
# #1: 2  / #2: 3 / result:  -1
# add
# #1: -1  / #2: 4 / result:  3
# div
# #1: 3  / #2: 5 / result:  0
# add
# #1: 0  / #2: 6 / result:  6
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# sub
# #1: 2  / #2: 3 / result:  -1
# div
# #1: -1  / #2: 4 / result:  0
# add
# #1: 0  / #2: 5 / result:  5
# add
# #1: 5  / #2: 6 / result:  11
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# sub
# #1: 3  / #2: 3 / result:  0
# mul
# #1: 0  / #2: 4 / result:  0
# div
# #1: 0  / #2: 5 / result:  0
# add
# #1: 0  / #2: 6 / result:  6
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# sub
# #1: 3  / #2: 3 / result:  0
# div
# #1: 0  / #2: 4 / result:  0
# mul
# #1: 0  / #2: 5 / result:  0
# add
# #1: 0  / #2: 6 / result:  6
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# sub
# #1: 2  / #2: 3 / result:  -1
# add
# #1: -1  / #2: 4 / result:  3
# add
# #1: 3  / #2: 5 / result:  8
# div
# #1: 8  / #2: 6 / result:  1
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# mul
# #1: -1  / #2: 3 / result:  -3
# add
# #1: -3  / #2: 4 / result:  1
# div
# #1: 1  / #2: 5 / result:  0
# add
# #1: 0  / #2: 6 / result:  6
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# mul
# #1: -1  / #2: 3 / result:  -3
# div
# #1: -3  / #2: 4 / result:  0
# add
# #1: 0  / #2: 5 / result:  5
# add
# #1: 5  / #2: 6 / result:  11
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# div
# #1: 3  / #2: 3 / result:  1
# sub
# #1: 1  / #2: 4 / result:  -3
# mul
# #1: -3  / #2: 5 / result:  -15
# add
# #1: -15  / #2: 6 / result:  -9
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# div
# #1: 3  / #2: 3 / result:  1
# mul
# #1: 1  / #2: 4 / result:  4
# sub
# #1: 4  / #2: 5 / result:  -1
# add
# #1: -1  / #2: 6 / result:  5
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# sub
# #1: 0  / #2: 3 / result:  -3
# add
# #1: -3  / #2: 4 / result:  1
# add
# #1: 1  / #2: 5 / result:  6
# mul
# #1: 6  / #2: 6 / result:  36
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# add
# #1: 0  / #2: 3 / result:  3
# add
# #1: 3  / #2: 4 / result:  7
# sub
# #1: 7  / #2: 5 / result:  2
# mul
# #1: 2  / #2: 6 / result:  12
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# add
# #1: 0  / #2: 3 / result:  3
# sub
# #1: 3  / #2: 4 / result:  -1
# add
# #1: -1  / #2: 5 / result:  4
# mul
# #1: 4  / #2: 6 / result:  24
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# add
# #1: 3  / #2: 3 / result:  6
# div
# #1: 6  / #2: 4 / result:  1
# mul
# #1: 1  / #2: 5 / result:  5
# sub
# #1: 5  / #2: 6 / result:  -1
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# add
# #1: 3  / #2: 3 / result:  6
# mul
# #1: 6  / #2: 4 / result:  24
# div
# #1: 24  / #2: 5 / result:  4
# sub
# #1: 4  / #2: 6 / result:  -2
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# div
# #1: 2  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# add
# #1: 4  / #2: 5 / result:  9
# sub
# #1: 9  / #2: 6 / result:  3
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# add
# #1: 0  / #2: 3 / result:  3
# mul
# #1: 3  / #2: 4 / result:  12
# sub
# #1: 12  / #2: 5 / result:  7
# add
# #1: 7  / #2: 6 / result:  13
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# div
# #1: 3  / #2: 3 / result:  1
# add
# #1: 1  / #2: 4 / result:  5
# mul
# #1: 5  / #2: 5 / result:  25
# sub
# #1: 25  / #2: 6 / result:  19
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# div
# #1: 3  / #2: 3 / result:  1
# mul
# #1: 1  / #2: 4 / result:  4
# add
# #1: 4  / #2: 5 / result:  9
# sub
# #1: 9  / #2: 6 / result:  3
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# add
# #1: 3  / #2: 3 / result:  6
# div
# #1: 6  / #2: 4 / result:  1
# sub
# #1: 1  / #2: 5 / result:  -4
# mul
# #1: -4  / #2: 6 / result:  -24
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# add
# #1: 3  / #2: 3 / result:  6
# sub
# #1: 6  / #2: 4 / result:  2
# div
# #1: 2  / #2: 5 / result:  0
# mul
# #1: 0  / #2: 6 / result:  0
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# add
# #1: 2  / #2: 3 / result:  5
# add
# #1: 5  / #2: 4 / result:  9
# sub
# #1: 9  / #2: 5 / result:  4
# div
# #1: 4  / #2: 6 / result:  0
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# add
# #1: 2  / #2: 3 / result:  5
# sub
# #1: 5  / #2: 4 / result:  1
# add
# #1: 1  / #2: 5 / result:  6
# div
# #1: 6  / #2: 6 / result:  1
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# mul
# #1: 0  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# sub
# #1: 4  / #2: 5 / result:  -1
# add
# #1: -1  / #2: 6 / result:  5
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# mul
# #1: 0  / #2: 3 / result:  0
# sub
# #1: 0  / #2: 4 / result:  -4
# add
# #1: -4  / #2: 5 / result:  1
# add
# #1: 1  / #2: 6 / result:  7
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# add
# #1: -1  / #2: 3 / result:  2
# add
# #1: 2  / #2: 4 / result:  6
# div
# #1: 6  / #2: 5 / result:  1
# mul
# #1: 1  / #2: 6 / result:  6
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# add
# #1: -1  / #2: 3 / result:  2
# div
# #1: 2  / #2: 4 / result:  0
# add
# #1: 0  / #2: 5 / result:  5
# mul
# #1: 5  / #2: 6 / result:  30
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# mul
# #1: 3  / #2: 3 / result:  9
# sub
# #1: 9  / #2: 4 / result:  5
# add
# #1: 5  / #2: 5 / result:  10
# div
# #1: 10  / #2: 6 / result:  1
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# mul
# #1: 3  / #2: 3 / result:  9
# add
# #1: 9  / #2: 4 / result:  13
# sub
# #1: 13  / #2: 5 / result:  8
# div
# #1: 8  / #2: 6 / result:  1
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# div
# #1: -1  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# add
# #1: 4  / #2: 5 / result:  9
# mul
# #1: 9  / #2: 6 / result:  54
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# div
# #1: 2  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# sub
# #1: 4  / #2: 5 / result:  -1
# add
# #1: -1  / #2: 6 / result:  5
# --------------------------------
# mul
# #1: 1  / #2: 2 / result:  2
# div
# #1: 2  / #2: 3 / result:  0
# sub
# #1: 0  / #2: 4 / result:  -4
# add
# #1: -4  / #2: 5 / result:  1
# add
# #1: 1  / #2: 6 / result:  7
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# mul
# #1: 0  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# add
# #1: 4  / #2: 5 / result:  9
# sub
# #1: 9  / #2: 6 / result:  3
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# sub
# #1: 0  / #2: 3 / result:  -3
# mul
# #1: -3  / #2: 4 / result:  -12
# add
# #1: -12  / #2: 5 / result:  -7
# add
# #1: -7  / #2: 6 / result:  -1
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# add
# #1: -1  / #2: 3 / result:  2
# add
# #1: 2  / #2: 4 / result:  6
# mul
# #1: 6  / #2: 5 / result:  30
# div
# #1: 30  / #2: 6 / result:  5
# --------------------------------
# sub
# #1: 1  / #2: 2 / result:  -1
# add
# #1: -1  / #2: 3 / result:  2
# mul
# #1: 2  / #2: 4 / result:  8
# add
# #1: 8  / #2: 5 / result:  13
# div
# #1: 13  / #2: 6 / result:  2
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# sub
# #1: 3  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# div
# #1: 4  / #2: 5 / result:  0
# mul
# #1: 0  / #2: 6 / result:  0
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# sub
# #1: 3  / #2: 3 / result:  0
# div
# #1: 0  / #2: 4 / result:  0
# add
# #1: 0  / #2: 5 / result:  5
# mul
# #1: 5  / #2: 6 / result:  30
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# sub
# #1: 3  / #2: 3 / result:  0
# add
# #1: 0  / #2: 4 / result:  4
# mul
# #1: 4  / #2: 5 / result:  20
# div
# #1: 20  / #2: 6 / result:  3
# --------------------------------
# add
# #1: 1  / #2: 2 / result:  3
# sub
# #1: 3  / #2: 3 / result:  0
# mul
# #1: 0  / #2: 4 / result:  0
# add
# #1: 0  / #2: 5 / result:  5
# div
# #1: 5  / #2: 6 / result:  0
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# sub
# #1: 0  / #2: 3 / result:  -3
# add
# #1: -3  / #2: 4 / result:  1
# mul
# #1: 1  / #2: 5 / result:  5
# add
# #1: 5  / #2: 6 / result:  11
# --------------------------------
# div
# #1: 1  / #2: 2 / result:  0
# add
# #1: 0  / #2: 3 / result:  3
# sub
# #1: 3  / #2: 4 / result:  -1
# mul
# #1: -1  / #2: 5 / result:  -5
# add
# #1: -5  / #2: 6 / result:  1
# [0,
#  12,
#  -5,
#  0,
#  29,
#  11,
#  1,
#  3,
#  7,
#  3,
#  7,
#  6,
#  26,
#  11,
#  6,
#  2,
#  -4,
#  1,
#  1,
#  6,
#  11,
#  6,
#  6,
#  1,
#  6,
#  11,
#  -9,
#  5,
#  36,
#  12,
#  24,
#  -1,
#  -2,
#  3,
#  13,
#  19,
#  3,
#  -24,
#  0,
#  0,
#  1,
#  5,
#  7,
#  6,
#  30,
#  1,
#  1,
#  54,
#  5,
#  7,
#  3,
#  -1,
#  5,
#  2,
#  0,
#  30,
#  3,
#  0,
#  11,
#  1]

# %%
max(real)
min(real)
# Out:
# -24

# %%
def result(result_list):
    return max(result_list), min(result_list)

# %%
result_max, result_min = result(real)

# %%
print(result_max)
print(result_min)
# Out:
# 54
# -24

# %%
c = -1 / 3
c
# Out:
# -0.3333333333333333

# %%
def input_values():
    n = int(input())
    numbers = list(map(int, input().split()))
    arithmetics = list(map(int, input().split()))
    
    return numbers, arithmetics

def add(a, b):
    return a + b

def sub(a, b):
    return a - b

def mul(a, b):
    return a * b

def div(a, b):
    return int(a / b)

def generate_operators_list(arithmetics):
    operators = {0: "add ", 1: "sub ", 2: "mul ", 3: "div "}
    operators_str = ""
    for idx in range(len(arithmetics)):
        if arithmetics[idx] != 0:
            operators_str += operators[idx]*arithmetics[idx]

    from itertools import permutations

    operators_permutation = permutations(operators_str.strip().split(" "), len(operators_str.strip().split(" ")) )
    set_permutation = list(set(operators_permutation))
    
    return set_permutation

def get_values(numbers, set_permutation):
    operator_func = {"add": add, "sub": sub, "mul": mul, "div": div}
    result_of_operations = []

    for idx_1 in range(len(set_permutation)):
        result_list = []
        result_list.append(numbers[0])
        for idx_2 in range(len(set_permutation[idx_1])):
            operator_idx = set_permutation[idx_1][idx_2]
            result_list.append(operator_func[operator_idx](result_list[idx_2], numbers[idx_2+1]))
        result_of_operations.append(result_list[-1])
    return result_of_operations
    
def get_max_min(result_list):
    return max(result_list), min(result_list)

# if "__name__" == "__main__":
numbers, arithmetics = input_values()
set_permutation = generate_operators_list(arithmetics)
result_list = get_values(numbers, set_permutation)
result_max, result_min = get_max_min(result_list)
    
print(result_max, result_min)
# Out:
# 6
# 1 2 3 4 5 6
# 2 1 1 1
# 54 -24
