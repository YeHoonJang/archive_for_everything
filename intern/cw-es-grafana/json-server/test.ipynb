# %%
from datetime import datetime
import time

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2018, 11, 7, 11, 18, 30, 336991)

# %%
with open("db.json", "r") as f:
    line = f.read()
    print(line)

# import json
# js_data = json.dumps(line)
# js_data
# Out:
# {
#   "search": [
#     {
#       "target": "es-test",
#       "id": 1
#     },
#     {
#       "target": "employess",
#       "id": 2
#     },
#     {
#       "target": "",
#       "id": 3
#     },
#     {
#       "target": "",
#       "id": 4
#     },
#     {
#       "target": "",
#       "id": 5
#     },
#     {
#       "target": "",
#       "id": 6
#     },
#     {
#       "target": "",
#       "id": 7
#     },
#     {
#       "target": "",
#       "id": 8
#     }
#   ],
#   "employees": [
#     {
#       "id": 1,
#       "name": "ini",
#       "salart": "10000"
#     },
#     {
#       "name": "INI",
#       "salary": "121212",
#       "id": 2
#     },
#     {
#       "name": "Lisa",
#       "salary": "2000",
#       "id": 3
#     }
#   ],
#   "es-test": [
#     {
#       "id": 1
#     },
#     {
#       "_index": "license-log2-2018-08",
#       "_type": "log2",
#       "_id": "49587319497620738222563045902568869099699373334616604674.0",
#       "_score": 1,
# ...

# %%
import ast
line = ast.literal_eval(line)
# Out:
# dict

# %%
line['es-test']
# Out:
# [{'id': 1},
#  {'_index': 'license-log2-2018-08',
#   '_type': 'log2',
#   '_id': '49587319497620738222563045902568869099699373334616604674.0',
#   '_score': 1,
#   '_source': {'time': '2018-08-16T10:11:53+00:00',
#    'status_code': 200,
#    'client_ip': '27.127.79.201',
#    'license_type': 'widevine',
#    'request_url': 'POST /widevine HTTP/1.1',
#    'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
#    'request_time': 0.067,
#    'server_ip': '172.31.44.251',
#    'key_ids': '2B45DB8F-1EFC-422E-A3C8-66833AD70138',
#    'access_key': '9640faa2-6555-4357-be3d-6dfcaee9f456',
#    'byte': 1023,
#    'custom_data': '',
#    'pid': '223862',
#    'one_time_use': 'true',
#    'persistent': 'false',
#    'expire': '2018-08-17T10:11:53Z',
#    'issue_id': 'f95dcbd9-1639-487d-a164-2a1eb9c21a25'},
#   'id': 2},
#  {'_index': 'license-log2-2018-08',
#   '_type': 'log2',
# ...

# %%
line_list = []
for i in line['es-test']:
    keys = i.keys()
    values = i.values()
    line_list.append(values)
    print(line_list)
# Out:
# [dict_values([1])]
# [dict_values([1]), dict_values(['license-log2-2018-08', 'log2', '49587319497620738222563045902568869099699373334616604674.0', 1, {'time': '2018-08-16T10:11:53+00:00', 'status_code': 200, 'client_ip': '27.127.79.201', 'license_type': 'widevine', 'request_url': 'POST /widevine HTTP/1.1', 'user_agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36', 'request_time': 0.067, 'server_ip': '172.31.44.251', 'key_ids': '2B45DB8F-1EFC-422E-A3C8-66833AD70138', 'access_key': '9640faa2-6555-4357-be3d-6dfcaee9f456', 'byte': 1023, 'custom_data': '', 'pid': '223862', 'one_time_use': 'true', 'persistent': 'false', 'expire': '2018-08-17T10:11:53Z', 'issue_id': 'f95dcbd9-1639-487d-a164-2a1eb9c21a25'}, 2])]
# ...
