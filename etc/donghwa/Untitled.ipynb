# %%
import pandas as pd

# %%
df = pd.read_csv("환경위생관리 현황.csv", encoding='cp949')

# %%
df.head()
# Out:
#      교육청명   교육지원청명          유치원명    설립유형  실내공기질 점검일자 실내공기질 점검결과 정기소독 의무대상시설여부  \
# 0  강원도교육청  강릉교육지원청         가온유치원  사립(사인)  2018-10-08         적합            실시
# 1  강원도교육청  강릉교육지원청   강동초등학교병설유치원  공립(병설)  2018-10-23         적합            실시
# 2  강원도교육청  강릉교육지원청         강릉유치원  사립(사인)  2018-10-02         적합            실시
# 3  강원도교육청  강릉교육지원청   강릉초등학교병설유치원  공립(병설)  2018-10-10         적합            실시
# 4  강원도교육청  강릉교육지원청  경포대초등학교병설유치원  공립(병설)  2018-10-02         적합            실시
#
#     정기소독 점검일자 정기소독 점검결과 음용수종류(먹는샘물(생수)) 음용수종류(정수기) 음용수종류(상수도) 음용수종류(지하수)  \
# 0  2019-04-10        실시             NaN          O          O        NaN
# 1  2019-02-26        실시             NaN        NaN          O        NaN
# 2  2019-03-21        실시             NaN          O          O        NaN
# 3  2019-02-28        실시             NaN        NaN          O        NaN
# 4  2019-02-01        실시             NaN          O          O        NaN
#
# ...
