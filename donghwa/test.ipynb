# %%
import pandas as pd

# %%
df = pd.read_csv("성적 예측 분석 데이터 수집 설문조사.csv")
df
# Out:
#                            타임스탬프      학년  19-1 전과목 중간고사 성적 평균  \
# 0   2019/05/17 10:57:50 오전 GMT+9  2학년 자연              92.2600
# 1   2019/05/17 11:05:25 오전 GMT+9  2학년 자연              78.0000
# 2    2019/05/17 2:30:49 오후 GMT+9  2학년 자연              64.2000
# 3    2019/05/17 2:31:38 오후 GMT+9  2학년 자연              75.6800
# 4    2019/05/19 4:18:08 오전 GMT+9  2학년 자연              80.5300
# 5   2019/05/23 11:59:29 오전 GMT+9  2학년 자연              70.0000
# 6   2019/05/23 12:01:02 오후 GMT+9  2학년 자연              78.3000
# 7    2019/05/23 7:51:46 오후 GMT+9  2학년 자연              93.0800
# 8    2019/05/23 9:42:33 오후 GMT+9  2학년 자연              89.7800
# 9   2019/05/23 10:35:08 오후 GMT+9  2학년 자연              78.2400
# 10  2019/05/24 12:29:45 오전 GMT+9  2학년 자연              79.6100
# 11   2019/05/24 2:35:27 오후 GMT+9  2학년 자연              62.0000
# 12   2019/05/24 2:40:05 오후 GMT+9  2학년 자연              65.8600
# 13   2019/05/24 5:15:32 오후 GMT+9  2학년 자연              87.4400
# ...

# %%
df.columns
# Out:
# Index(['타임스탬프', '학년', '19-1 전과목 중간고사 성적 평균', '국어 (국어, 문학, 고전)',
#        '영어(영어, 영어 I, 심화 영어 독해 I)',
#        '수학(수학, 수학 I, 수학연습 I, 수학연습 II, 확률과 통계, 기하와 벡터)', '통합 과학', '한문 I',
#        '한국지리', '윤리와 사상', '물리학 I', '화학 I', '생명과학 I', '지구과학 I', '사회문화', '동아시아사',
#        '생활과 윤리', '과학', '과학 II(물리학 II, 화학 II, 생명과학 II, 지구과학II)',
#        '일주일에 TV를 며칠 시청하시나요?', '1회 평균 TV 시청 시간은 몇 시간인가요?',
#        'TV를 시청하실 때 주로 어떤 장르의 프로그램을 시청하시나요?', '본인은 현재 스마트폰을 소유하고 있나요?',
#        '하루에 스마트폰을 평균 몇 시간 사용하시나요?', '스마트폰을 주로 어떤 용도로 사용하시나요?',
#        '방과 후 학습 장소는 주로 어디입니까?',
#        '현재 사교육을 받고 있습니까?  (과외나 인터넷 강의 포함 단, EBS 인터넷 강의 제외)',
#        '현재 받고 있는 사교육의 개수를 입력해주세요. ', '현재 받고 있는 사교육의 형태를 선택해주세요.',
#        '하루 평균 수면 시간은 어느 정도입니까?', '하루에 운동을 평균 몇 시간 하나요?', '어떤 형태의 운동을 주로 하나요?',
#        '평소에 아침식사를 하나요?'],
#       dtype='object')

# %%
df['스마트폰을 주로 어떤 용도로 사용하시나요?'][4]
# Out:
# '문자 메시지 및 메신저 (카카오톡, 라인 등);음악감상;콘텐츠 관람 (유투브, 웹툰, 넷플릭스 등);모바일 게임'

# %%
df.사회문화.isnull().sum()
# Out:
# 81

# %%
df['국어 (국어, 문학, 고전)'].isnull().sum()
# Out:
# 0
