# %%
import pandas as pd

# %%
df = pd.read_csv("성적 예측 분석 데이터 수집 설문조사.csv")
df
# Out:
#                           타임스탬프      학년  19-1 전과목 중간고사 성적 평균  국어 (국어, 문학, 고전)  \
# 0   2019/05/16 9:35:36 오후 GMT+9  3학년 자연                    2                2
# 1  2019/05/16 10:07:10 오후 GMT+9  3학년 자연                    2                2
# 2  2019/05/16 11:04:38 오후 GMT+9  3학년 자연                   50               50
# 3  2019/05/17 12:27:49 오전 GMT+9  3학년 자연                   50               50
# 4  2019/05/17 12:45:59 오전 GMT+9  3학년 자연                   10               10
#
#    영어(영어, 영어 I, 심화 영어 독해 I)  수학(수학, 수학 I, 수학연습 I, 수학연습 II, 확률과 통계, 기하와 벡터)  \
# 0                         1                                              2
# 1                         1                                              2
# 2                        50                                             50
# 3                        50                                             50
# 4                        10                                             10
#
# ...

# %%
df.columns
# Out:
# Index(['타임스탬프', '학년', '19-1 전과목 중간고사 성적 평균', '국어 (국어, 문학, 고전)',
#        '영어(영어, 영어 I, 심화 영어 독해 I)',
#        '수학(수학, 수학 I, 수학연습 I, 수학연습 II, 확률과 통계, 기하와 벡터)', '통합 과학', '한문 I',
#        '한국지리', '윤리와 사상', '물리학 I', '화학 I', '생명과학 I', '지구과학 I', '사회문화', '동아시아사',
#        '생활과 윤리', '과학', '과학 II(물리학 II, 화학 II, 생명과학 II, 지구과학II)',
#        '일주일에 TV를 며칠 시청하시나요?', '1회 평균 TV 시청 시간은 몇 시간인가요?',
#        'TV를 시청하실 때 주로 어떤 장르의 프로그램을 시청하시나요?', '본인은 현재 스마트폰을 소유하고 있나요?',
#        '하루에 스마트폰을 평균 몇 시간 사용하시나요?', '스마트폰을 주로 어떤 용도로 사용하시나요?',
#        '방과 후 학습 장소는 주로 어디입니까?', '하루 평균 수면 시간은 어느 정도입니까?',
#        '하루에 운동을 평균 몇 시간 하나요?', '어떤 형태의 운동을 주로 하나요?'],
#       dtype='object')

# %%
df['스마트폰을 주로 어떤 용도로 사용하시나요?'][4]
# Out:
# '문자 메시지 및 메신저 (카카오톡, 라인 등);SNS (페이스북, 인스타그램, 트위터 등);콘텐츠 관람 (유투브, 웹툰, 넷플릭스 등)'
